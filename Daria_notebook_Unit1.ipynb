# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("/"))
# Out:
# ['home', 'usr', '.DS_Store', 'bin', 'sbin', '.file', 'etc', 'var', 'Library', 'System', '.VolumeIcon.icns', '.fseventsd', 'private', '.vol', 'Users', 'Applications', 'opt', 'dev', 'Volumes', 'tmp', 'cores']

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
max_budget=data[(data['budget']==data['budget'].max())].original_title
display(max_budget)
answer_ls.append(4)
answer_ls
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object
# [4]

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
max_length=data[(data['runtime']==data['runtime'].max())].original_title
display(max_length)
answer_ls.append(2)
answer_ls
# Out:
# 1158    Gods and Generals
# Name: original_title, dtype: object
# [4, 2]

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
min_length=data[(data['runtime']==data['runtime'].min())].original_title
display(min_length)
answer_ls.append(3)
answer_ls
# Out:
# 769    Winnie the Pooh
# Name: original_title, dtype: object
# [4, 2, 3]

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
average_length=data.runtime.mean()
display(average_length)
answer_ls.append(2)
answer_ls
# Out:
# 109.65343915343915
# [4, 2, 3, 2]

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
median_length=data.runtime.median()
display(median_length)
answer_ls.append(1)
answer_ls
# Out:
# 106.5
# [4, 2, 3, 2, 1]

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit']=data['revenue']-data['budget']
max_profit=data[(data['profit']==data['profit'].max())].original_title
display(max_profit)
answer_ls.append(5)
answer_ls
# Out:
# 239    Avatar
# Name: original_title, dtype: object
# [4, 2, 3, 2, 1, 5]

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
min_profit=data[(data['profit']==data['profit'].min())].original_title
display(min_profit)
answer_ls.append(2)
answer_ls
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object
# [4, 2, 3, 2, 1, 5, 2]

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data[(data['profit']>0)].imdb_id.value_counts()
# Out:
# tt1482459    1
# tt0340163    1
# tt0300532    1
# tt1690953    1
# tt0220506    1
#             ..
# tt1142988    1
# tt3460252    1
# tt0217505    1
# tt0286716    1
# tt0380510    1
# Name: imdb_id, Length: 1478, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data_2008=data[data['release_year']==2008]
max_profit_2008=data_2008[(data_2008['profit']==data_2008['profit'].max())].imdb_id
display(max_profit_2008)
# Out:
# 600    tt0468569
# Name: imdb_id, dtype: object

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data_2012_2014=data[(data['release_year']>=2012)&(data['release_year']<=2014)]
min_profit_2012_2014=data_2012_2014[(data_2012_2014['profit']==data_2012_2014['profit'].min())].imdb_id
display(min_profit_2012_2014)
# Out:
# 1246    tt1210819
# Name: imdb_id, dtype: object

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5]

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
Counter(data.genres.str.split('|').sum()).most_common()
# Out:
# [('Drama', 782),
#  ('Comedy', 683),
#  ('Thriller', 597),
#  ('Action', 583),
#  ('Adventure', 416),
#  ('Crime', 315),
#  ('Romance', 308),
#  ('Family', 260),
#  ('Science Fiction', 248),
#  ('Fantasy', 223),
#  ('Horror', 176),
#  ('Mystery', 168),
#  ('Animation', 139),
#  ('Music', 64),
#  ('History', 62),
#  ('War', 58),
#  ('Western', 20),
#  ('Documentary', 8),
#  ('Foreign', 2)]

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3]

# %% [raw]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
genres_profit=data[data['profit']>0]
Counter(genres_profit.genres.str.split('|').sum()).most_common()
# Out:
# [('Drama', 560),
#  ('Comedy', 551),
#  ('Thriller', 446),
#  ('Action', 444),
#  ('Adventure', 337),
#  ('Romance', 242),
#  ('Crime', 231),
#  ('Family', 226),
#  ('Science Fiction', 195),
#  ('Fantasy', 188),
#  ('Horror', 150),
#  ('Animation', 120),
#  ('Mystery', 119),
#  ('Music', 47),
#  ('History', 46),
#  ('War', 41),
#  ('Western', 12),
#  ('Documentary', 7)]

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1]

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
Counter(data.director.str.split('|').sum()).most_common()
# Out:
# [('Steven Soderbergh', 13),
#  ('Ridley Scott', 12),
#  ('Clint Eastwood', 12),
#  ('Robert Rodriguez', 11),
#  ('Steven Spielberg', 10),
#  ('Shawn Levy', 10),
#  ('Peter Farrelly', 10),
#  ('Bobby Farrelly', 9),
#  ('Tim Burton', 9),
#  ('Antoine Fuqua', 8),
#  ('Ron Howard', 8),
#  ('M. Night Shyamalan', 8),
#  ('Christopher Nolan', 8),
#  ('Peter Jackson', 8),
#  ('Michael Bay', 8),
#  ('Brett Ratner', 8),
#  ('Todd Phillips', 8),
#  ('Adam Shankman', 8),
#  ('Gore Verbinski', 8),
#  ('Quentin Tarantino', 7),
#  ('Paul W.S. Anderson', 7),
#  ('Lasse HallstrÃ¶m', 7),
#  ('Dennis Dugan', 7),
#  ('Marc Forster', 7),
#  ('Francis Lawrence', 6),
#  ('Adam McKay', 6),
#  ('Robert Zemeckis', 6),
#  ('Andy Fickman', 6),
#  ('David Fincher', 6),
#  ('Tim Story', 6),
#  ('Zack Snyder', 6),
#  ('Robert Luketic', 6),
#  ('Steve Carr', 6),
#  ('Sam Raimi', 6),
#  ('Tony Scott', 6),
#  ('Joel Coen', 6),
#  ('Martin Scorsese', 6),
#  ('Danny Boyle', 6),
#  ('Louis Leterrier', 6),
# ...

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3]

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
dir_profit=data[data['profit']>0]
dir_profit.director.value_counts()
# Out:
# Ridley Scott                         12
# Clint Eastwood                       10
# Steven Spielberg                     10
# Steven Soderbergh                    10
# Shawn Levy                            9
#                                      ..
# Steve Box|Nick Park                   1
# Wong Kar-wai                          1
# Elizabeth Allen Rosenbaum             1
# Shekhar Kapur                         1
# Alastair Fothergill|Mark Linfield     1
# Name: director, Length: 774, dtype: int64

# %%
answer_ls.append(4)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4]

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
directors = data['director'].copy()
pd.Series({x:data[data.director.str.contains(x)].profit.sum() for x in directors}).sort_values(ascending = False)
# Out:
# Peter Jackson                                5202593685
# Lee Unkrich|David Silverman|Pete Docter      3768734349
# David Yates                                  3379295625
# Christopher Nolan                            3162548502
# Andrew Adamson|Kelly Asbury|Conrad Vernon    2962413461
#                                                 ...
# Ron Underwood                                 -92896027
# James L. Brooks                               -96289726
# Walter Hill|Jack Sholder                     -128283462
# Walter Hill                                  -128283462
# Sngmoo Lee                                   -413912431
# Length: 958, dtype: int64

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5]

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
actors = set(data.cast.str.split('|').sum()) 
pd.Series({x:data[data.cast.str.contains(x)].profit.sum() for x in actors}).sort_values(ascending = False)
# Out:
# Emma Watson           6666245597
# Daniel Radcliffe      6514990281
# Rupert Grint          6408638290
# Ian McKellen          6087375777
# Robert Downey Jr.     5316030161
#                          ...
# Elisabeth Harnois     -111007242
# Emilio EchevarrÃ­a    -119180039
# Kate Bosworth         -369455668
# Ti Lung               -413912431
# Jang Dong-gun         -413912431
# Length: 3408, dtype: int64

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1]

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
actors = set(data.cast.str.split('|').sum()) 
data_2012=data[data['release_year']==2012]
pd.Series({x:data_2012[data_2012.cast.str.contains(x)].profit.sum() for x in actors}).sort_values(ascending = False)
# Out:
# Chris Hemsworth      1542450773
# Denis Leary          1319460639
# Robert Downey Jr.    1299557910
# Chris Evans          1299557910
# Mark Ruffalo         1299557910
#                         ...
# Malin Ã…kerman        -43733509
# Timothy Spall         -51893525
# James Kidnie          -51893525
# Heidi Hawkins         -51893525
# Kirsten Dunst         -68109207
# Length: 3408, dtype: int64

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3]

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
actors = set(data.cast.str.split('|').sum()) 
data_profit_mean=data[data['budget']>=data['budget'].mean()]
Counter(data_profit_mean.cast.str.split('|').sum()).most_common()
# Out:
# [('Matt Damon', 18),
#  ('Adam Sandler', 17),
#  ('Angelina Jolie', 16),
#  ('Tom Cruise', 15),
#  ('Samuel L. Jackson', 15),
#  ('Eddie Murphy', 15),
#  ('Mark Wahlberg', 14),
#  ('Hugh Jackman', 14),
#  ('Ben Stiller', 14),
#  ('Jamie Foxx', 14),
#  ('Russell Crowe', 14),
#  ('Johnny Depp', 13),
#  ('Jude Law', 13),
#  ('Bruce Willis', 13),
#  ('Will Smith', 13),
#  ('Dwayne Johnson', 12),
#  ('Ian McKellen', 12),
#  ('Brad Pitt', 12),
#  ('Owen Wilson', 12),
#  ('Cameron Diaz', 12),
#  ('Nicolas Cage', 12),
#  ('Robert De Niro', 12),
#  ('Leonardo DiCaprio', 11),
#  ('Daniel Craig', 11),
#  ('Robert Downey Jr.', 11),
#  ('Steve Buscemi', 11),
#  ('Vin Diesel', 10),
#  ('Mark Ruffalo', 10),
#  ('Jack Black', 10),
#  ('Denzel Washington', 10),
#  ('Emma Watson', 10),
#  ('Gary Oldman', 10),
#  ('Tom Hanks', 10),
#  ('Orlando Bloom', 10),
#  ('Ralph Fiennes', 9),
#  ('Cate Blanchett', 9),
#  ('Michael Caine', 9),
#  ('Ewan McGregor', 9),
#  ('Paul Bettany', 9),
# ...

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3]

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
nicolas=data[data.cast.str.contains('Nicolas Cage')] 
Counter(nicolas.genres.str.split('|').sum()).most_common()
# Out:
# [('Action', 17),
#  ('Thriller', 15),
#  ('Drama', 12),
#  ('Crime', 10),
#  ('Fantasy', 8),
#  ('Adventure', 7),
#  ('Comedy', 6),
#  ('Science Fiction', 4),
#  ('Mystery', 3),
#  ('Animation', 3),
#  ('Family', 3),
#  ('History', 2),
#  ('War', 1),
#  ('Horror', 1),
#  ('Romance', 1)]

# %%
answer_ls.append(2)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2]

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
studios=set(data.production_companies.str.split('|').sum())
pd.Series({x:data[data.production_companies.str.contains(x)].production_companies.count() for x in studios}).sort_values(ascending = False)
# Out:
# Universal                                                              185
# Warner Bros.                                                           183
# Universal Pictures                                                     175
# Columbia Pictures                                                      163
# Paramount Pictures                                                     122
#                                                                       ...
# Moving Picture Company (MPC)                                             0
# Flower Films (II)                                                        0
# Monolith Pictures (III)                                                  0
# Instituto de la CinematografÃ­a y de las Artes Audiovisuales (ICAA)      0
# Anton Capital Entertainment (ACE)                                        0
# Length: 1772, dtype: int64

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1]

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
data_2015=data[data['release_year']==2015]
studios_2015=set(data_2015.production_companies.str.split('|').sum())
pd.Series({x:data[data.production_companies.str.contains(x)].production_companies.count() for x in studios_2015}).sort_values(ascending = False)
# Out:
# Warner Bros.                              183
# Universal Pictures                        175
# Columbia Pictures                         163
# Paramount Pictures                        122
# Twentieth Century Fox Film Corporation    109
#                                          ...
# Metro-Goldwyn-Mayer (MGM)                   0
# Moving Picture Company (MPC)                0
# Sony Pictures Entertainment (SPE)           0
# Iron Horse Entertainment (II)               0
# Universal Pictures International (UPI)      0
# Length: 246, dtype: int64

# %%
answer_ls.append(4)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4]

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
comedy=data[data.genres.str.contains('Comedy')] 
studios=set(comedy.production_companies.str.split('|').sum())
pd.Series({x:comedy[comedy.production_companies.str.contains(x)].profit.sum() for x in studios}).sort_values(ascending = False)
# Out:
# Universal                   9130349034
# Universal Pictures          8952422726
# Twentieth Century Fox       8239362666
# Disney                      8006316328
# Walt Disney Pictures        7669710326
#                                ...
# Warner Bros. Pictures        -54738687
# Shangri-La Entertainment     -55170786
# Dark Horse Entertainment     -68351500
# Road Rebel                   -71331093
# Mel's Cite du Cinema         -92896027
# Length: 702, dtype: int64

# %%
answer_ls.append(2)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4, 2]

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
data_2012=data[data['release_year']==2012]
studios_2012=set(data_2012.production_companies.str.split('|').sum())
pd.Series({x:data_2012[data_2012.production_companies.str.contains(x)].profit.sum() for x in studios_2012}).sort_values(ascending = False)
# Out:
# Columbia Pictures     2501406608
# Universal Pictures    1981011579
# Marvel Studios        1299557910
# Warner Bros.          1258020056
# Relativity Media      1032593938
#                          ...
# Transfilm              -51893525
# Studio 37              -51893525
# Onyx Films             -51893525
# CinÃ©+                 -70341621
# France 2 CinÃ©ma       -82545651
# Length: 236, dtype: int64

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4, 2, 3]

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
par=data[data.production_companies.str.contains('Paramount Pictures')]
min_profit_par=par[(par['profit']==par['profit'].min())].imdb_id
display(min_profit_par)
# Out:
# 926    tt0267626
# Name: imdb_id, dtype: object

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4, 2, 3, 1]

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby('release_year')['profit'].sum().sort_values(0, ascending=False)
# Out:
# release_year
# 2015    18668572378
# 2014    16397812953
# 2012    16077001687
# 2013    15243179791
# 2011    14730241341
# 2009    13423744372
# 2010    13117292530
# 2008    11663881990
# 2007    11565911801
# 2004     9634180720
# 2003     9228823312
# 2002     9002361487
# 2005     8981925558
# 2006     8691077320
# 2001     7950614865
# 2000     6101399805
# Name: profit, dtype: int64

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4, 2, 3, 1, 5]

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
WB=data[data.production_companies.str.contains('Warner Bros')]
WB.groupby('release_year')['profit'].sum().sort_values(0, ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4, 2, 3, 2, 1, 5, 2, 1, 4, 5, 3, 1, 3, 4, 5, 1, 3, 3, 2, 1, 4, 2, 3, 1, 5, 1]

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data['release_date'] = pd.to_datetime(data['release_date'])
display(data)
data.release_date.dt.month.value_counts()
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
answer_ls.append(4)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4]

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
data_sum=data[data.release_date.dt.month.isin([6, 7, 8,])]
data_sum.imdb_id.count()
# Out:
# 450

# %%
answer_ls.append(2)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2]

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
data_win=data[data.release_date.dt.month.isin([12, 1, 2,])]
Counter(data_win.director.str.split('|').sum()).most_common()
# Out:
# [('Peter Jackson', 7),
#  ('Clint Eastwood', 6),
#  ('Steven Soderbergh', 6),
#  ('Shawn Levy', 4),
#  ('Nancy Meyers', 4),
#  ('Martin Scorsese', 4),
#  ('Adam Shankman', 4),
#  ('Ridley Scott', 3),
#  ('Rob Marshall', 3),
#  ('Tim Burton', 3),
#  ('Steve Carr', 3),
#  ('Patrick Lussier', 3),
#  ('Donald Petrie', 3),
#  ('Marc Lawrence', 3),
#  ('Lasse HallstrÃ¶m', 3),
#  ('Edward Zwick', 3),
#  ('Jason Friedberg', 3),
#  ('Aaron Seltzer', 3),
#  ('Peter Farrelly', 3),
#  ('Steven Spielberg', 3),
#  ('Wayne Wang', 3),
#  ('Quentin Tarantino', 2),
#  ('Adam McKay', 2),
#  ('Michael Mann', 2),
#  ('Glenn Ficarra', 2),
#  ('John Requa', 2),
#  ('Pierre Morel', 2),
#  ('Wes Anderson', 2),
#  ('Paul Thomas Anderson', 2),
#  ('Jaume Collet-Serra', 2),
#  ('George Clooney', 2),
#  ('Shana Feste', 2),
#  ('Ken Kwapis', 2),
#  ('Henry Selick', 2),
#  ('P.J. Hogan', 2),
#  ('David S. Goyer', 2),
#  ('Paul McGuigan', 2),
#  ('Marcus Nispel', 2),
#  ('Andrzej Bartkowiak', 2),
# ...

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5]

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data['month'] = data.release_date.apply(lambda x: x.month)
data.groupby('month')['profit'].sum().sort_values(0, ascending=False)
# Out:
# month
# 6     27551262500
# 12    26563071474
# 5     25039516141
# 11    18654155473
# 7     18307895020
# 3     13720216540
# 10    12994907859
# 4     12876005537
# 9     10878921041
# 8      9640610446
# 2      8854574425
# 1      5396885454
# Name: profit, dtype: int64

# %%
answer_ls.append(2)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2]

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['len'] = data.original_title.str.len()
studios=set(data.production_companies.str.split('|').sum())
pd.Series({x:data[data.production_companies.str.contains(x)].len.mean() for x in studios}).sort_values(ascending = False)
# Out:
# Four By Two Productions                                83.0
# Jim Henson Company, The                                59.0
# Dos Corazones                                          47.0
# Polsky Films                                           46.0
# Museum Canada Productions                              46.0
#                                                        ...
# Canadian Film or Video Production Tax Credit (CPTC)     NaN
# Baumgarten Management and Productions (BMP)             NaN
# British Broadcasting Corporation (BBC)                  NaN
# Film Capital Europe Funds (FCEF )                       NaN
# Industrial Light & Magic (ILM)                          NaN
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5]

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['title_words'] = data.original_title.map(lambda x: len(x.split(' ')))
studios=set(data.production_companies.str.split('|').sum())
pd.Series({x:data[data.production_companies.str.contains(x)].title_words.mean() for x in studios}).sort_values(ascending = False)
# Out:
# Four By Two Productions                                12.0
# Jim Henson Company, The                                10.0
# The Saul Zaentz Company                                 9.0
# Dos Corazones                                           9.0
# Polsky Films                                            9.0
#                                                        ...
# Canadian Film or Video Production Tax Credit (CPTC)     NaN
# Baumgarten Management and Productions (BMP)             NaN
# British Broadcasting Corporation (BBC)                  NaN
# Film Capital Europe Funds (FCEF )                       NaN
# Industrial Light & Magic (ILM)                          NaN
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5]

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
len(set(data.original_title.str.lower().str.split().sum()))
# Out:
# 2461

# %%
answer_ls.append(3)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  3]

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
quantile = data.quantile(0.99, numeric_only=True)['vote_average']
data[data['vote_average']>quantile]['original_title']
# Out:
# 9                                          Inside Out
# 34                                               Room
# 118                                      Interstellar
# 119                           Guardians of the Galaxy
# 125                                The Imitation Game
# 128                                         Gone Girl
# 138                          The Grand Budapest Hotel
# 370                                         Inception
# 600                                   The Dark Knight
# 873                                       The Pianist
# 1082    The Lord of the Rings: The Return of the King
# 1184                          The Wolf of Wall Street
# 1192                                 12 Years a Slave
# 1801                                          Memento
# Name: original_title, dtype: object

# %%
answer_ls.append(1)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  3,
#  1]

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
from itertools import combinations
pairs = Counter()
for i in range(0,len(data)):
    artists = data.cast[i].split('|')
    for j in combinations(artists, 2):
        if j not in pairs:
            pairs[j] = 1
        else:
            pairs[j] += 1
pairs.most_common(5)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8),
#  (('Daniel Radcliffe', 'Emma Watson'), 8),
#  (('Rupert Grint', 'Emma Watson'), 7),
#  (('Ben Stiller', 'Owen Wilson'), 6),
#  (('Johnny Depp', 'Helena Bonham Carter'), 6)]

# %%
answer_ls.append(5)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  3,
#  1,
#  5]

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data['profit_positive'] = data['profit'] > 0
directors_mean=data.groupby('director')['profit_positive'].mean()
directors_mean
# Out:
# director
# Aaron Seltzer|Jason Friedberg    1.000
# Adam McKay                       1.000
# Adam Shankman                    0.875
# Adam Wingard                     0.000
# Adrian Lyne                      1.000
#                                  ...
# Wong Kar-wai                     1.000
# Woody Allen                      1.000
# Xavier Gens                      1.000
# Zack Snyder                      1.000
# Zal Batmanglij                   0.000
# Name: profit_positive, Length: 958, dtype: float64

# %%
directors_mean['Quentin Tarantino']
# Out:
# 1.0

# %%
directors_mean['Steven Soderbergh']
# Out:
# 0.7692307692307693

# %%
directors_mean['Robert Rodriguez']
# Out:
# 0.8571428571428571

# %% [markdown]
# # Submission

# %%
directors_mean['Christopher Nolan']
# Out:
# 1.0

# %%
directors_mean['Clint Eastwood']
# Out:
# 0.8333333333333334

# %%
answer_ls.append(4)
answer_ls
# Out:
# [4,
#  2,
#  3,
#  2,
#  1,
#  5,
#  2,
#  1,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  3,
#  1,
#  5,
#  4]

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
